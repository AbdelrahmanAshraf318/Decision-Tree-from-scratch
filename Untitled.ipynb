# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 1 : </b>
#        Importing Libraries
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 2 : </b>
#        Load Dataset and Deal with missing values by dropping the row which contains missing values
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
""" The following three lines is for convert all values which contains '?' into NAN  """
missing_values = ["?"]

# %%
dataset = pd.read_csv('house-votes-84-data.txt' , na_values = missing_values)

# %%
dataset
# Out:
#      republican    n    y n.1  y.1  y.2 y.3  n.2  n.3  n.4  y.4  ?  y.5 y.6  \
# 0    republican    n    y   n    y    y   y    n    n    n    n  n    y   y
# 1      democrat  NaN    y   y  NaN    y   y    n    n    n    n  y    n   y
# 2      democrat    n    y   y    n  NaN   y    n    n    n    n  y    n   y
# 3      democrat    y    y   y    n    y   y    n    n    n    n  y  NaN   y
# 4      democrat    n    y   y    n    y   y    n    n    n    n  n    n   y
# ..          ...  ...  ...  ..  ...  ...  ..  ...  ...  ...  ... ..  ...  ..
# 429  republican    n    n   y    y    y   y    n    n    y    y  n    y   y
# 430    democrat    n    n   y    n    n   n    y    y    y    y  n    n   n
# 431  republican    n  NaN   n    y    y   y    n    n    n    n  y    y   y
# 432  republican    n    n   n    y    y   y  NaN  NaN  NaN  NaN  n    y   y
# 433  republican    n    y   n    y    y   y    n    n    n    y  n    y   y
#
#     y.7  n.5  y.8
# 0     y    n  NaN
# 1     y    n    n
# 2     n    n    y
# 3     y    y    y
# 4     y    y    y
# ..   ..  ...  ...
# 429   y    n    y
# 430   n    n    y
# 431   y    n    y
# 432   y    n    y
# 433   y  NaN    n
#
# [434 rows x 17 columns]

# %%
# Drops all rows with NaN values
dataset.dropna(axis=0,inplace=True)

# %%
dataset.dropna(axis=0,inplace=True, how='all')

# %%
dataset
# Out:
#      republican  n  y n.1 y.1 y.2 y.3 n.2 n.3 n.4 y.4  ? y.5 y.6 y.7 n.5 y.8
# 4      democrat  n  y   y   n   y   y   n   n   n   n  n   n   y   y   y   y
# 7    republican  n  y   n   y   y   y   n   n   n   n  n   y   y   y   n   y
# 18     democrat  y  y   y   n   n   n   y   y   y   n  y   n   n   n   y   y
# 22     democrat  y  y   y   n   n   n   y   y   y   n  n   n   n   n   y   y
# 24     democrat  y  n   y   n   n   n   y   y   y   y  n   n   n   n   y   y
# ..          ... .. ..  ..  ..  ..  ..  ..  ..  ..  .. ..  ..  ..  ..  ..  ..
# 422    democrat  n  y   y   n   n   y   y   y   y   n  y   n   n   y   y   y
# 425    democrat  y  n   y   n   n   n   y   y   y   y  n   n   n   n   y   y
# 426  republican  n  n   n   y   y   y   y   y   n   y  n   y   y   y   n   y
# 429  republican  n  n   y   y   y   y   n   n   y   y  n   y   y   y   n   y
# 430    democrat  n  n   y   n   n   n   y   y   y   y  n   n   n   n   n   y
#
# [232 rows x 17 columns]

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 3 : </b>
#        Define X and y
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
X = dataset.iloc[: , 1:].values

# %%
X
# Out:
# array([['n', 'y', 'y', ..., 'y', 'y', 'y'],
#        ['n', 'y', 'n', ..., 'y', 'n', 'y'],
#        ['y', 'y', 'y', ..., 'n', 'y', 'y'],
#        ...,
#        ['n', 'n', 'n', ..., 'y', 'n', 'y'],
#        ['n', 'n', 'y', ..., 'y', 'n', 'y'],
#        ['n', 'n', 'y', ..., 'n', 'n', 'y']], dtype=object)

# %%
X.shape
# Out:
# (232, 16)

# %%
y = dataset.iloc[: , 0:1].values

# %%
y
# Out:
# array([['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['democrat'],
#        ['republican'],
#        ['republican'],
#        ['democrat']], dtype=object)

# %%
y.shape
# Out:
# (232, 1)

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 4 : </b>
#        Split the data into train and test
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
indeces = len(X) #434

# %%
splitIndex = int(np.ceil(0.25 * indeces))

# %%
splitIndex
# Out:
# 58

# %%
X_train = X[0:splitIndex , :]

# %%
X_train
# Out:
# array([['n', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y',
#         'y', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'y',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'y',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'y',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'y', 'y', 'y'],
#        ['n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'y', 'y', 'y', 'y', 'n', 'y', 'y', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'n',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y']], dtype=object)

# %%
X_train.shape
# Out:
# (58, 16)

# %%
y_train = y[0:splitIndex , :]

# %%
y_train.shape
# Out:
# (58, 1)

# %%
X_test = X[splitIndex: , :]

# %%
X_test
# Out:
# array([['y', 'y', 'y', ..., 'y', 'n', 'y'],
#        ['n', 'y', 'y', ..., 'n', 'y', 'y'],
#        ['n', 'n', 'n', ..., 'y', 'n', 'n'],
#        ...,
#        ['n', 'n', 'n', ..., 'y', 'n', 'y'],
#        ['n', 'n', 'y', ..., 'y', 'n', 'y'],
#        ['n', 'n', 'y', ..., 'n', 'n', 'y']], dtype=object)

# %%
X_test.shape
# Out:
# (174, 16)

# %%
y_test = y[splitIndex: , :]

# %%
y_test.shape
# Out:
# (174, 1)

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 5 : </b>
#        Information Gain
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
""" This function calculate the information gain for only one feature """
def information_gain(feature , y):
    H_parent = 0
    H_child1 = 0
    H_child2 = 0
    
    counter1 = 0 #To count how many number of democrat
    counter2 = 0 #To count how many number of republican
    for i in range(len(y)):
        if y[i] == "republican" :
            counter1 = counter1 + 1
        else:
            counter2 = counter2 + 1
            
    
            
    counterForYes1 = 0 #To count how many number of republican when the feature is yes
    counterForYes2 = 0 #To count how many number of democrat when the feature is yes
    for i in range(len(y)):
        if y[i] == "republican" and feature[i] == 'y':
            counterForYes1 = counterForYes1 + 1
        elif y[i] == "democrat" and feature[i] == 'y':
            counterForYes2 = counterForYes2 + 1
            
    if counterForYes1 == 0:
        H_child1 = '%.2f'%(- ( counterForYes2 / (counterForYes1 + counterForYes2) * np.log2(counterForYes2 / (counterForYes1 + counterForYes2))))
    elif counterForYes2 == 0:
        H_child1 = '%.2f'%(( -counterForYes1 / (counterForYes1 + counterForYes2) * np.log2(counterForYes1 / (counterForYes1 + counterForYes2))) )
    elif counterForYes1 == 0 and counterForYes2 == 0:
        H_child1 = 0
    else:
        H_child1 = '%.2f'%(( -counterForYes1 / (counterForYes1 + counterForYes2) * np.log2(counterForYes1 / (counterForYes1 + counterForYes2))) - ( counterForYes2 / (counterForYes1 + counterForYes2) * np.log2(counterForYes2 / (counterForYes1 + counterForYes2))))
    
    
    counterForNo1 = 0 #To count how many number of republican when the feature is No
    counterForNo2 = 0 #To count how many number of democrat when the feature is No
    for i in range(len(y)):
        if y[i] == "republican" and feature[i] == 'n':
            counterForNo1 = counterForNo1 + 1
        elif y[i] == "democrat" and feature[i] == 'n':
            counterForNo2 = counterForNo2 + 1
            
    
    if counterForNo1 == 0:
        H_child2 = '%.2f'%(- ( counterForNo2 / (counterForNo1 + counterForNo2) * np.log2(counterForNo2 / (counterForNo1 + counterForNo2))))
    elif counterForNo2 == 0:
         H_child2 = '%.2f'%(( -counterForNo1 / (counterForNo1 + counterForNo2) * np.log2(counterForNo1 / (counterForNo1 + counterForNo2))) )
    elif counterForNo1 == 0 and counterForNo2 == 0:
        H_child2 = 0
    else:
         H_child2 = '%.2f'%(( -counterForNo1 / (counterForNo1 + counterForNo2) * np.log2(counterForNo1 / (counterForNo1 + counterForNo2))) - ( counterForNo2 / (counterForNo1 + counterForNo2) * np.log2(counterForNo2 / (counterForNo1 + counterForNo2))))
    
    
    H_parent = '%.2f'%(( -counter1 / (counter1 + counter2) * np.log2(counter1 / (counter1 + counter2))) - ( counter2 / (counter1 + counter2) * np.log2(counter2 / (counter1 + counter2))))
            
    
   
    gain = '%.2f'%(float(H_parent) - float(H_child1) - float(H_child2))
    
    return gain

# %%
print(information_gain(X_train[: , 15] , y_train))
# Out:
# -0.29

# %%
X_train[: , 3]
# Out:
# array(['n', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'n', 'y', 'n', 'y', 'n',
#        'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#        'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y', 'y', 'n', 'y', 'y', 'n',
#        'y', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'n', 'n', 'y', 'n', 'n'], dtype=object)
