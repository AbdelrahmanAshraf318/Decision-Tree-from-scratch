# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 1 : </b>
#        Importing Libraries
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 2 : </b>
#        Load Dataset and Deal with missing values by dropping the row which contains missing values
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
""" The following three lines is for convert all values which contains '?' into NAN  """
missing_values = ["?"]

# %%
dataset = pd.read_csv('house-votes-84-data.txt' , na_values = missing_values)

# %%
dataset
# Out:
#      republican    n    y n.1  y.1  y.2 y.3  n.2  n.3  n.4  y.4  ?  y.5 y.6  \
# 0    republican    n    y   n    y    y   y    n    n    n    n  n    y   y
# 1      democrat  NaN    y   y  NaN    y   y    n    n    n    n  y    n   y
# 2      democrat    n    y   y    n  NaN   y    n    n    n    n  y    n   y
# 3      democrat    y    y   y    n    y   y    n    n    n    n  y  NaN   y
# 4      democrat    n    y   y    n    y   y    n    n    n    n  n    n   y
# ..          ...  ...  ...  ..  ...  ...  ..  ...  ...  ...  ... ..  ...  ..
# 429  republican    n    n   y    y    y   y    n    n    y    y  n    y   y
# 430    democrat    n    n   y    n    n   n    y    y    y    y  n    n   n
# 431  republican    n  NaN   n    y    y   y    n    n    n    n  y    y   y
# 432  republican    n    n   n    y    y   y  NaN  NaN  NaN  NaN  n    y   y
# 433  republican    n    y   n    y    y   y    n    n    n    y  n    y   y
#
#     y.7  n.5  y.8
# 0     y    n  NaN
# 1     y    n    n
# 2     n    n    y
# 3     y    y    y
# 4     y    y    y
# ..   ..  ...  ...
# 429   y    n    y
# 430   n    n    y
# 431   y    n    y
# 432   y    n    y
# 433   y  NaN    n
#
# [434 rows x 17 columns]

# %%
# Drops all rows with NaN values
dataset.dropna(axis=0,inplace=True)

# %%
dataset.dropna(axis=0,inplace=True, how='all')

# %%
dataset
# Out:
#      republican  n  y n.1 y.1 y.2 y.3 n.2 n.3 n.4 y.4  ? y.5 y.6 y.7 n.5 y.8
# 4      democrat  n  y   y   n   y   y   n   n   n   n  n   n   y   y   y   y
# 7    republican  n  y   n   y   y   y   n   n   n   n  n   y   y   y   n   y
# 18     democrat  y  y   y   n   n   n   y   y   y   n  y   n   n   n   y   y
# 22     democrat  y  y   y   n   n   n   y   y   y   n  n   n   n   n   y   y
# 24     democrat  y  n   y   n   n   n   y   y   y   y  n   n   n   n   y   y
# ..          ... .. ..  ..  ..  ..  ..  ..  ..  ..  .. ..  ..  ..  ..  ..  ..
# 422    democrat  n  y   y   n   n   y   y   y   y   n  y   n   n   y   y   y
# 425    democrat  y  n   y   n   n   n   y   y   y   y  n   n   n   n   y   y
# 426  republican  n  n   n   y   y   y   y   y   n   y  n   y   y   y   n   y
# 429  republican  n  n   y   y   y   y   n   n   y   y  n   y   y   y   n   y
# 430    democrat  n  n   y   n   n   n   y   y   y   y  n   n   n   n   n   y
#
# [232 rows x 17 columns]

# %%
column = ['Class Name' , 'handicapped-infants', 'water-project-cost-sharing', 'adoption-of-the-budget-resolution', 'physician-fee-freeze', 'el-salvador-aid', 'religious-groups-in-schools', 'anti-satellite-test-ban' , 'aid-to-nicaraguan-contras' , 'mx-missile' , 'immigration' , 'synfuels-corporation-cutback' , 'education-spending' , 'superfund-right-to-sue' , 'crime' , 'duty-free-exports' , 'export-administration-act-south-africa']
col_names = ['handicapped-infants', 'water-project-cost-sharing', 'adoption-of-the-budget-resolution', 'physician-fee-freeze', 'el-salvador-aid', 'religious-groups-in-schools', 'anti-satellite-test-ban' , 'aid-to-nicaraguan-contras' , 'mx-missile' , 'immigration' , 'synfuels-corporation-cutback' , 'education-spending' , 'superfund-right-to-sue' , 'crime' , 'duty-free-exports' , 'export-administration-act-south-africa']

# %%
dataset.columns = column
dataset
# Out:
#      Class Name handicapped-infants water-project-cost-sharing  \
# 4      democrat                   n                          y
# 7    republican                   n                          y
# 18     democrat                   y                          y
# 22     democrat                   y                          y
# 24     democrat                   y                          n
# ..          ...                 ...                        ...
# 422    democrat                   n                          y
# 425    democrat                   y                          n
# 426  republican                   n                          n
# 429  republican                   n                          n
# 430    democrat                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 4                                   y                    n               y
# 7                                   n                    y               y
# 18                                  y                    n               n
# 22                                  y                    n               n
# 24                                  y                    n               n
# ..                                ...                  ...             ...
# 422                                 y                    n               n
# 425                                 y                    n               n
# 426                                 n                    y               y
# 429                                 y                    y               y
# 430                                 y                    n               n
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 4                             y                       n
# 7                             y                       n
# 18                            n                       y
# 22                            n                       y
# 24                            n                       y
# ..                          ...                     ...
# 422                           y                       y
# 425                           n                       y
# 426                           y                       y
# 429                           y                       n
# 430                           n                       y
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 4                           n          n           n
# 7                           n          n           n
# 18                          y          y           n
# 22                          y          y           n
# 24                          y          y           y
# ..                        ...        ...         ...
# 422                         y          y           n
# 425                         y          y           y
# 426                         y          n           y
# 429                         n          y           y
# 430                         y          y           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 4                              n                  n                      y
# 7                              n                  y                      y
# 18                             y                  n                      n
# 22                             n                  n                      n
# 24                             n                  n                      n
# ..                           ...                ...                    ...
# 422                            y                  n                      n
# 425                            n                  n                      n
# 426                            n                  y                      y
# 429                            n                  y                      y
# 430                            n                  n                      n
#
#     crime duty-free-exports export-administration-act-south-africa
# 4       y                 y                                      y
# 7       y                 n                                      y
# 18      n                 y                                      y
# 22      n                 y                                      y
# 24      n                 y                                      y
# ..    ...               ...                                    ...
# 422     y                 y                                      y
# 425     n                 y                                      y
# 426     y                 n                                      y
# 429     y                 n                                      y
# 430     n                 n                                      y
#
# [232 rows x 17 columns]

# %%
print(dataset.shape[0])
# Out:
# 232

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 3 : </b>
#        Define X and y
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
X = dataset[col_names]

# %%
X
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 4                     n                          y
# 7                     n                          y
# 18                    y                          y
# 22                    y                          y
# 24                    y                          n
# ..                  ...                        ...
# 422                   n                          y
# 425                   y                          n
# 426                   n                          n
# 429                   n                          n
# 430                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 4                                   y                    n               y
# 7                                   n                    y               y
# 18                                  y                    n               n
# 22                                  y                    n               n
# 24                                  y                    n               n
# ..                                ...                  ...             ...
# 422                                 y                    n               n
# 425                                 y                    n               n
# 426                                 n                    y               y
# 429                                 y                    y               y
# 430                                 y                    n               n
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 4                             y                       n
# 7                             y                       n
# 18                            n                       y
# 22                            n                       y
# 24                            n                       y
# ..                          ...                     ...
# 422                           y                       y
# 425                           n                       y
# 426                           y                       y
# 429                           y                       n
# 430                           n                       y
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 4                           n          n           n
# 7                           n          n           n
# 18                          y          y           n
# 22                          y          y           n
# 24                          y          y           y
# ..                        ...        ...         ...
# 422                         y          y           n
# 425                         y          y           y
# 426                         y          n           y
# 429                         n          y           y
# 430                         y          y           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 4                              n                  n                      y
# 7                              n                  y                      y
# 18                             y                  n                      n
# 22                             n                  n                      n
# 24                             n                  n                      n
# ..                           ...                ...                    ...
# 422                            y                  n                      n
# 425                            n                  n                      n
# 426                            n                  y                      y
# 429                            n                  y                      y
# 430                            n                  n                      n
#
#     crime duty-free-exports export-administration-act-south-africa
# 4       y                 y                                      y
# 7       y                 n                                      y
# 18      n                 y                                      y
# 22      n                 y                                      y
# 24      n                 y                                      y
# ..    ...               ...                                    ...
# 422     y                 y                                      y
# 425     n                 y                                      y
# 426     y                 n                                      y
# 429     y                 n                                      y
# 430     n                 n                                      y
#
# [232 rows x 16 columns]

# %%
X.shape
# Out:
# (232, 16)

# %%
y = dataset[['Class Name']]

# %%
y
# Out:
#      Class Name
# 4      democrat
# 7    republican
# 18     democrat
# 22     democrat
# 24     democrat
# ..          ...
# 422    democrat
# 425    democrat
# 426  republican
# 429  republican
# 430    democrat
#
# [232 rows x 1 columns]

# %%
y.shape
# Out:
# (232, 1)

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 4 : </b>
#        Split the data into train and test
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
indeces = len(X) #434

# %%
splitIndex = int(np.ceil(0.25 * indeces))

# %%
splitIndex
# Out:
# 58

# %%
X_train = X.iloc[0:splitIndex , :].values

# %%
X_train
# Out:
# array([['n', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y',
#         'y', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'y',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'y',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'y', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'y',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'y', 'y', 'y'],
#        ['n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'y', 'y', 'y', 'y', 'n', 'y', 'y', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'n', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'n'],
#        ['n', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y', 'y', 'y', 'n', 'y',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'n', 'y', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'y', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'n', 'y'],
#        ['y', 'n', 'n', 'n', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'n',
#         'y', 'n', 'y'],
#        ['y', 'n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'y', 'n', 'n',
#         'y', 'n', 'y'],
#        ['y', 'y', 'y', 'n', 'n', 'n', 'n', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y'],
#        ['n', 'y', 'n', 'y', 'y', 'y', 'n', 'n', 'n', 'n', 'n', 'y', 'y',
#         'y', 'n', 'y'],
#        ['n', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'y', 'n', 'n', 'n',
#         'n', 'y', 'y'],
#        ['y', 'n', 'y', 'n', 'n', 'n', 'y', 'y', 'y', 'n', 'y', 'n', 'n',
#         'n', 'y', 'y']], dtype=object)

# %%
print(X_train.shape)
X_train = pd.DataFrame(X_train , columns = col_names)
X_train
# Out:
# (58, 16)
#    handicapped-infants water-project-cost-sharing  \
# 0                    n                          y
# 1                    n                          y
# 2                    y                          y
# 3                    y                          y
# 4                    y                          n
# 5                    y                          n
# 6                    y                          y
# 7                    y                          n
# 8                    y                          y
# 9                    n                          y
# 10                   y                          y
# 11                   n                          y
# 12                   y                          y
# 13                   n                          y
# 14                   y                          y
# 15                   n                          y
# 16                   y                          n
# 17                   y                          n
# 18                   y                          n
# 19                   y                          y
# 20                   y                          y
# 21                   y                          y
# 22                   y                          y
# 23                   n                          y
# 24                   n                          y
# 25                   n                          y
# 26                   n                          y
# 27                   n                          y
# 28                   y                          y
# 29                   y                          y
# 30                   n                          y
# 31                   n                          y
# 32                   y                          y
# 33                   y                          y
# 34                   y                          n
# 35                   y                          n
# 36                   n                          y
# 37                   n                          y
# 38                   y                          y
# 39                   n                          n
# 40                   n                          n
# 41                   n                          n
# 42                   n                          n
# 43                   n                          n
# 44                   n                          n
# 45                   n                          y
# 46                   y                          n
# 47                   y                          n
# 48                   y                          n
# 49                   y                          n
# 50                   y                          n
# 51                   y                          y
# 52                   y                          n
# 53                   y                          n
# 54                   y                          y
# 55                   n                          y
# 56                   n                          n
# 57                   y                          n
#
#    adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                  y                    n               y
# 1                                  n                    y               y
# 2                                  y                    n               n
# 3                                  y                    n               n
# 4                                  y                    n               n
# 5                                  y                    n               n
# 6                                  y                    n               n
# 7                                  n                    y               y
# 8                                  y                    n               n
# 9                                  n                    y               y
# 10                                 y                    n               n
# 11                                 n                    y               y
# 12                                 y                    n               n
# 13                                 n                    y               y
# 14                                 n                    y               y
# 15                                 n                    y               y
# 16                                 y                    n               n
# 17                                 y                    n               n
# 18                                 y                    n               n
# 19                                 y                    n               n
# 20                                 y                    n               n
# 21                                 y                    n               n
# 22                                 n                    y               y
# 23                                 n                    y               y
# 24                                 n                    y               y
# 25                                 n                    y               y
# 26                                 n                    y               y
# 27                                 n                    y               y
# 28                                 y                    n               n
# 29                                 n                    y               y
# 30                                 n                    y               y
# 31                                 n                    y               y
# 32                                 y                    n               n
# 33                                 y                    y               n
# 34                                 y                    y               y
# 35                                 y                    n               n
# 36                                 y                    y               y
# 37                                 y                    y               y
# 38                                 y                    n               y
# 39                                 n                    y               y
# 40                                 n                    y               y
# 41                                 n                    y               y
# 42                                 y                    n               y
# 43                                 n                    y               y
# 44                                 n                    y               y
# 45                                 y                    n               y
# 46                                 y                    n               n
# 47                                 y                    n               n
# 48                                 y                    n               n
# 49                                 y                    n               y
# 50                                 n                    n               y
# 51                                 y                    n               n
# 52                                 n                    n               y
# 53                                 y                    n               y
# 54                                 y                    n               n
# 55                                 n                    y               y
# 56                                 y                    n               n
# 57                                 y                    n               n
#
#    religious-groups-in-schools anti-satellite-test-ban  \
# 0                            y                       n
# 1                            y                       n
# 2                            n                       y
# 3                            n                       y
# 4                            n                       y
# 5                            n                       y
# 6                            n                       y
# 7                            n                       y
# 8                            n                       y
# 9                            y                       n
# 10                           n                       y
# 11                           y                       n
# 12                           n                       y
# 13                           y                       n
# 14                           y                       n
# 15                           y                       n
# 16                           n                       y
# 17                           n                       y
# 18                           n                       y
# 19                           n                       y
# 20                           n                       y
# 21                           n                       y
# 22                           y                       n
# 23                           y                       n
# 24                           y                       n
# 25                           y                       n
# 26                           y                       n
# 27                           y                       n
# 28                           n                       y
# 29                           y                       y
# 30                           y                       y
# 31                           y                       n
# 32                           n                       y
# 33                           n                       y
# 34                           n                       y
# 35                           y                       y
# 36                           y                       n
# 37                           y                       n
# 38                           y                       n
# 39                           n                       n
# 40                           y                       n
# 41                           y                       n
# 42                           y                       n
# 43                           y                       n
# 44                           y                       n
# 45                           y                       y
# 46                           n                       y
# 47                           n                       y
# 48                           n                       y
# 49                           y                       n
# 50                           y                       y
# 51                           y                       y
# 52                           y                       n
# 53                           y                       y
# 54                           n                       n
# 55                           y                       n
# 56                           n                       y
# 57                           n                       y
#
#    aid-to-nicaraguan-contras mx-missile immigration  \
# 0                          n          n           n
# 1                          n          n           n
# 2                          y          y           n
# 3                          y          y           n
# 4                          y          y           y
# 5                          y          y           n
# 6                          y          y           n
# 7                          y          y           n
# 8                          y          y           n
# 9                          n          n           n
# 10                         y          y           y
# 11                         n          n           n
# 12                         y          y           n
# 13                         n          n           n
# 14                         n          n           n
# 15                         n          n           y
# 16                         y          y           y
# 17                         y          y           n
# 18                         y          y           n
# 19                         y          y           n
# 20                         y          n           n
# 21                         y          y           n
# 22                         n          n           y
# 23                         n          n           y
# 24                         n          n           y
# 25                         n          n           y
# 26                         n          n           y
# 27                         n          n           n
# 28                         y          y           n
# 29                         n          n           n
# 30                         n          n           n
# 31                         n          n           y
# 32                         y          y           n
# 33                         y          y           y
# 34                         n          y           y
# 35                         y          y           y
# 36                         n          n           y
# 37                         y          y           y
# 38                         n          n           y
# 39                         n          n           y
# 40                         n          n           y
# 41                         n          n           n
# 42                         n          n           y
# 43                         n          n           y
# 44                         n          n           n
# 45                         n          y           y
# 46                         y          y           y
# 47                         y          y           y
# 48                         n          y           y
# 49                         n          n           n
# 50                         n          n           y
# 51                         y          y           y
# 52                         n          n           n
# 53                         n          n           n
# 54                         y          y           n
# 55                         n          n           n
# 56                         y          y           y
# 57                         y          y           n
#
#    synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                             n                  n                      y
# 1                             n                  y                      y
# 2                             y                  n                      n
# 3                             n                  n                      n
# 4                             n                  n                      n
# 5                             y                  n                      n
# 6                             y                  n                      n
# 7                             n                  y                      y
# 8                             y                  n                      n
# 9                             n                  y                      y
# 10                            n                  n                      y
# 11                            n                  y                      y
# 12                            n                  n                      n
# 13                            n                  y                      y
# 14                            n                  n                      y
# 15                            n                  y                      y
# 16                            y                  n                      y
# 17                            n                  n                      n
# 18                            n                  n                      n
# 19                            n                  n                      n
# 20                            n                  n                      n
# 21                            y                  n                      n
# 22                            n                  y                      y
# 23                            y                  y                      y
# 24                            y                  y                      y
# 25                            n                  y                      y
# 26                            n                  y                      y
# 27                            n                  y                      y
# 28                            y                  n                      n
# 29                            n                  y                      y
# 30                            y                  y                      y
# 31                            n                  y                      y
# 32                            n                  n                      n
# 33                            y                  n                      n
# 34                            n                  n                      y
# 35                            y                  n                      n
# 36                            y                  n                      y
# 37                            y                  y                      y
# 38                            y                  n                      y
# 39                            n                  y                      y
# 40                            n                  y                      y
# 41                            n                  y                      y
# 42                            y                  y                      y
# 43                            n                  y                      y
# 44                            n                  y                      y
# 45                            y                  n                      y
# 46                            n                  n                      n
# 47                            y                  n                      n
# 48                            y                  n                      n
# 49                            n                  n                      n
# 50                            y                  n                      n
# 51                            n                  n                      n
# 52                            y                  y                      n
# 53                            y                  n                      n
# 54                            y                  n                      n
# 55                            n                  y                      y
# 56                            n                  n                      n
# 57                            y                  n                      n
#
#    crime duty-free-exports export-administration-act-south-africa
# 0      y                 y                                      y
# 1      y                 n                                      y
# 2      n                 y                                      y
# 3      n                 y                                      y
# 4      n                 y                                      y
# 5      n                 y                                      y
# 6      n                 y                                      y
# 7      y                 n                                      y
# 8      n                 y                                      y
# 9      y                 n                                      n
# 10     n                 y                                      y
# 11     y                 n                                      y
# 12     n                 y                                      y
# 13     y                 n                                      n
# 14     y                 n                                      y
# 15     y                 n                                      n
# 16     n                 y                                      y
# 17     n                 n                                      y
# 18     n                 y                                      y
# 19     n                 n                                      y
# 20     y                 n                                      y
# 21     n                 y                                      y
# 22     y                 n                                      n
# 23     y                 n                                      n
# 24     y                 n                                      y
# 25     y                 n                                      y
# 26     y                 n                                      y
# 27     y                 n                                      n
# 28     n                 n                                      y
# 29     y                 n                                      y
# 30     y                 n                                      y
# 31     y                 n                                      n
# 32     n                 y                                      y
# 33     y                 n                                      y
# 34     y                 n                                      y
# 35     y                 y                                      y
# 36     y                 n                                      n
# 37     y                 n                                      y
# 38     y                 n                                      y
# 39     y                 n                                      n
# 40     y                 n                                      y
# 41     y                 n                                      n
# 42     y                 n                                      y
# 43     y                 n                                      n
# 44     y                 n                                      n
# 45     y                 n                                      y
# 46     n                 y                                      y
# 47     n                 y                                      y
# 48     n                 y                                      y
# 49     n                 n                                      y
# 50     y                 n                                      y
# 51     n                 n                                      y
# 52     y                 n                                      y
# 53     y                 n                                      y
# 54     n                 y                                      y
# 55     y                 n                                      y
# 56     n                 y                                      y
# 57     n                 y                                      y

# %%
y_train = y.iloc[0:splitIndex , :].values
y_train = pd.DataFrame(y_train , columns = ['Class Name'])
y_train
# Out:
#     Class Name
# 0     democrat
# 1   republican
# 2     democrat
# 3     democrat
# 4     democrat
# 5     democrat
# 6     democrat
# 7   republican
# 8     democrat
# 9   republican
# 10    democrat
# 11  republican
# 12    democrat
# 13  republican
# 14  republican
# 15  republican
# 16    democrat
# 17    democrat
# 18    democrat
# 19    democrat
# 20    democrat
# 21    democrat
# 22  republican
# 23  republican
# 24  republican
# 25  republican
# 26  republican
# 27  republican
# 28    democrat
# 29  republican
# 30  republican
# 31  republican
# 32    democrat
# 33  republican
# 34  republican
# 35    democrat
# 36    democrat
# 37    democrat
# 38    democrat
# 39  republican
# 40  republican
# 41  republican
# 42    democrat
# 43  republican
# 44  republican
# 45    democrat
# 46    democrat
# 47    democrat
# 48    democrat
# 49    democrat
# 50    democrat
# 51    democrat
# 52    democrat
# 53    democrat
# 54    democrat
# 55  republican
# 56    democrat
# 57    democrat

# %%
y_train.shape
# Out:
# (58, 1)

# %%
X_test = X.iloc[splitIndex: , :].values
X_test = pd.DataFrame(X_test , columns = col_names)
X_test
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     y                          y
# 1                     n                          y
# 2                     n                          n
# 3                     n                          n
# 4                     n                          n
# ..                  ...                        ...
# 169                   n                          y
# 170                   y                          n
# 171                   n                          n
# 172                   n                          n
# 173                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   y                    y               y
# 1                                   y                    n               n
# 2                                   n                    y               y
# 3                                   n                    y               y
# 4                                   y                    n               n
# ..                                ...                  ...             ...
# 169                                 y                    n               n
# 170                                 y                    n               n
# 171                                 n                    y               y
# 172                                 y                    y               y
# 173                                 y                    n               n
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             n                       y
# 1                             n                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 169                           y                       y
# 170                           n                       y
# 171                           y                       y
# 172                           y                       n
# 173                           n                       y
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           n
# 1                           y          y           y
# 2                           n          n           n
# 3                           n          n           y
# 4                           y          y           y
# ..                        ...        ...         ...
# 169                         y          y           n
# 170                         y          y           y
# 171                         y          n           y
# 172                         n          y           y
# 173                         y          y           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              n                  y                      y
# 1                              y                  n                      n
# 2                              n                  y                      y
# 3                              n                  y                      n
# 4                              n                  n                      n
# ..                           ...                ...                    ...
# 169                            y                  n                      n
# 170                            n                  n                      n
# 171                            n                  y                      y
# 172                            n                  y                      y
# 173                            n                  n                      n
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       n                 y                                      y
# 2       y                 n                                      n
# 3       y                 n                                      y
# 4       y                 n                                      y
# ..    ...               ...                                    ...
# 169     y                 y                                      y
# 170     n                 y                                      y
# 171     y                 n                                      y
# 172     y                 n                                      y
# 173     n                 n                                      y
#
# [174 rows x 16 columns]

# %%
X_test
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     y                          y
# 1                     n                          y
# 2                     n                          n
# 3                     n                          n
# 4                     n                          n
# ..                  ...                        ...
# 169                   n                          y
# 170                   y                          n
# 171                   n                          n
# 172                   n                          n
# 173                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   y                    y               y
# 1                                   y                    n               n
# 2                                   n                    y               y
# 3                                   n                    y               y
# 4                                   y                    n               n
# ..                                ...                  ...             ...
# 169                                 y                    n               n
# 170                                 y                    n               n
# 171                                 n                    y               y
# 172                                 y                    y               y
# 173                                 y                    n               n
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             n                       y
# 1                             n                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 169                           y                       y
# 170                           n                       y
# 171                           y                       y
# 172                           y                       n
# 173                           n                       y
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           n
# 1                           y          y           y
# 2                           n          n           n
# 3                           n          n           y
# 4                           y          y           y
# ..                        ...        ...         ...
# 169                         y          y           n
# 170                         y          y           y
# 171                         y          n           y
# 172                         n          y           y
# 173                         y          y           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              n                  y                      y
# 1                              y                  n                      n
# 2                              n                  y                      y
# 3                              n                  y                      n
# 4                              n                  n                      n
# ..                           ...                ...                    ...
# 169                            y                  n                      n
# 170                            n                  n                      n
# 171                            n                  y                      y
# 172                            n                  y                      y
# 173                            n                  n                      n
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       n                 y                                      y
# 2       y                 n                                      n
# 3       y                 n                                      y
# 4       y                 n                                      y
# ..    ...               ...                                    ...
# 169     y                 y                                      y
# 170     n                 y                                      y
# 171     y                 n                                      y
# 172     y                 n                                      y
# 173     n                 n                                      y
#
# [174 rows x 16 columns]

# %%
X_test.shape
# Out:
# (174, 16)

# %%
y_test = y.iloc[splitIndex: , :].values
y_test = pd.DataFrame(y_test , columns = ['Class Name'])
y_test
# Out:
#      Class Name
# 0    republican
# 1      democrat
# 2    republican
# 3    republican
# 4      democrat
# ..          ...
# 169    democrat
# 170    democrat
# 171  republican
# 172  republican
# 173    democrat
#
# [174 rows x 1 columns]

# %%
y_test.shape
# Out:
# (174, 1)

# %%
feature_array = X_train.to_numpy()
#print(feature_array)
print(feature_array[: , 1])
print(feature_array.shape)
# Out:
# ['y' 'y' 'y' 'y' 'n' 'n' 'y' 'n' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'n' 'n'
#  'n' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'y' 'n' 'n'
#  'y' 'y' 'y' 'n' 'n' 'n' 'n' 'n' 'n' 'y' 'n' 'n' 'n' 'n' 'n' 'y' 'n' 'n'
#  'y' 'y' 'n' 'n']
# (58, 16)

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 5 : </b>
#        Information Gain
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
""" This function calculate the information gain for only one feature """
def information_gain(featureDataFrame , colIndex , y_DataFrame):
    
    feature_array = featureDataFrame.to_numpy()
    #print(feature_array)
    feature = (feature_array[: , colIndex]).reshape(len(featureDataFrame) , 1)
    
    #print(feature)
    #print(feature.shape)
    
    #print("***********************************************")
    
    y = (y_DataFrame.to_numpy()).reshape(len(y_DataFrame) , 1)
    #print(y)
    
    H_parent = 0
    H_child1 = 0
    H_child2 = 0
    
    counter1 = 0 #To count how many number of democrat
    counter2 = 0 #To count how many number of republican
    for i in range(len(y)):
        if y[i] == "republican" :
            counter1 = counter1 + 1
        else:
            counter2 = counter2 + 1
            
    
            
    counterForYes1 = 0 #To count how many number of republican when the feature is yes
    counterForYes2 = 0 #To count how many number of democrat when the feature is yes
    for i in range(len(y)):
        if y[i] == "republican" and feature[i] == 'y':
            counterForYes1 = counterForYes1 + 1
        elif y[i] == "democrat" and feature[i] == 'y':
            counterForYes2 = counterForYes2 + 1
            
    if counterForYes1 == 0:
        H_child1 = (- ( counterForYes2 / (counterForYes1 + counterForYes2) * np.log2(counterForYes2 / (counterForYes1 + counterForYes2))))
    elif counterForYes2 == 0:
        H_child1 = (( -counterForYes1 / (counterForYes1 + counterForYes2) * np.log2(counterForYes1 / (counterForYes1 + counterForYes2))) )
    elif counterForYes1 == 0 and counterForYes2 == 0:
        H_child1 = 0
    else:
        H_child1 = (( -counterForYes1 / (counterForYes1 + counterForYes2) * np.log2(counterForYes1 / (counterForYes1 + counterForYes2))) - ( counterForYes2 / (counterForYes1 + counterForYes2) * np.log2(counterForYes2 / (counterForYes1 + counterForYes2))))
    
    
    counterForNo1 = 0 #To count how many number of republican when the feature is No
    counterForNo2 = 0 #To count how many number of democrat when the feature is No
    for i in range(len(y)):
        if y[i] == "republican" and feature[i] == 'n':
            counterForNo1 = counterForNo1 + 1
        elif y[i] == "democrat" and feature[i] == 'n':
            counterForNo2 = counterForNo2 + 1
            
    
    if counterForNo1 == 0:
        H_child2 = (- ( counterForNo2 / (counterForNo1 + counterForNo2) * np.log2(counterForNo2 / (counterForNo1 + counterForNo2))))
    elif counterForNo2 == 0:
         H_child2 = (( -counterForNo1 / (counterForNo1 + counterForNo2) * np.log2(counterForNo1 / (counterForNo1 + counterForNo2))) )
    elif counterForNo1 == 0 and counterForNo2 == 0:
        H_child2 = 0
    else:
         H_child2 = (( -counterForNo1 / (counterForNo1 + counterForNo2) * np.log2(counterForNo1 / (counterForNo1 + counterForNo2))) - ( counterForNo2 / (counterForNo1 + counterForNo2) * np.log2(counterForNo2 / (counterForNo1 + counterForNo2))))
    
    
    H_parent = (( -counter1 / (counter1 + counter2) * np.log2(counter1 / (counter1 + counter2))) - ( counter2 / (counter1 + counter2) * np.log2(counter2 / (counter1 + counter2))))
            
    
   
    gain = (float(H_parent) - float(H_child1) - float(H_child2))
    
    return gain

# %%
print(information_gain(X_train , 15 , y_train))
# Out:
# -0.2943485580776111

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 6 : </b>
#        Find the best attribute
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
X_train
# Out:
#    handicapped-infants water-project-cost-sharing  \
# 0                    n                          y
# 1                    n                          y
# 2                    y                          y
# 3                    y                          y
# 4                    y                          n
# 5                    y                          n
# 6                    y                          y
# 7                    y                          n
# 8                    y                          y
# 9                    n                          y
# 10                   y                          y
# 11                   n                          y
# 12                   y                          y
# 13                   n                          y
# 14                   y                          y
# 15                   n                          y
# 16                   y                          n
# 17                   y                          n
# 18                   y                          n
# 19                   y                          y
# 20                   y                          y
# 21                   y                          y
# 22                   y                          y
# 23                   n                          y
# 24                   n                          y
# 25                   n                          y
# 26                   n                          y
# 27                   n                          y
# 28                   y                          y
# 29                   y                          y
# 30                   n                          y
# 31                   n                          y
# 32                   y                          y
# 33                   y                          y
# 34                   y                          n
# 35                   y                          n
# 36                   n                          y
# 37                   n                          y
# 38                   y                          y
# 39                   n                          n
# 40                   n                          n
# 41                   n                          n
# 42                   n                          n
# 43                   n                          n
# 44                   n                          n
# 45                   n                          y
# 46                   y                          n
# 47                   y                          n
# 48                   y                          n
# 49                   y                          n
# 50                   y                          n
# 51                   y                          y
# 52                   y                          n
# 53                   y                          n
# 54                   y                          y
# 55                   n                          y
# 56                   n                          n
# 57                   y                          n
#
#    adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                  y                    n               y
# 1                                  n                    y               y
# 2                                  y                    n               n
# 3                                  y                    n               n
# 4                                  y                    n               n
# 5                                  y                    n               n
# 6                                  y                    n               n
# 7                                  n                    y               y
# 8                                  y                    n               n
# 9                                  n                    y               y
# 10                                 y                    n               n
# 11                                 n                    y               y
# 12                                 y                    n               n
# 13                                 n                    y               y
# 14                                 n                    y               y
# 15                                 n                    y               y
# 16                                 y                    n               n
# 17                                 y                    n               n
# 18                                 y                    n               n
# 19                                 y                    n               n
# 20                                 y                    n               n
# 21                                 y                    n               n
# 22                                 n                    y               y
# 23                                 n                    y               y
# 24                                 n                    y               y
# 25                                 n                    y               y
# 26                                 n                    y               y
# 27                                 n                    y               y
# 28                                 y                    n               n
# 29                                 n                    y               y
# 30                                 n                    y               y
# 31                                 n                    y               y
# 32                                 y                    n               n
# 33                                 y                    y               n
# 34                                 y                    y               y
# 35                                 y                    n               n
# 36                                 y                    y               y
# 37                                 y                    y               y
# 38                                 y                    n               y
# 39                                 n                    y               y
# 40                                 n                    y               y
# 41                                 n                    y               y
# 42                                 y                    n               y
# 43                                 n                    y               y
# 44                                 n                    y               y
# 45                                 y                    n               y
# 46                                 y                    n               n
# 47                                 y                    n               n
# 48                                 y                    n               n
# 49                                 y                    n               y
# 50                                 n                    n               y
# 51                                 y                    n               n
# 52                                 n                    n               y
# 53                                 y                    n               y
# 54                                 y                    n               n
# 55                                 n                    y               y
# 56                                 y                    n               n
# 57                                 y                    n               n
#
#    religious-groups-in-schools anti-satellite-test-ban  \
# 0                            y                       n
# 1                            y                       n
# 2                            n                       y
# 3                            n                       y
# 4                            n                       y
# 5                            n                       y
# 6                            n                       y
# 7                            n                       y
# 8                            n                       y
# 9                            y                       n
# 10                           n                       y
# 11                           y                       n
# 12                           n                       y
# 13                           y                       n
# 14                           y                       n
# 15                           y                       n
# 16                           n                       y
# 17                           n                       y
# 18                           n                       y
# 19                           n                       y
# 20                           n                       y
# 21                           n                       y
# 22                           y                       n
# 23                           y                       n
# 24                           y                       n
# 25                           y                       n
# 26                           y                       n
# 27                           y                       n
# 28                           n                       y
# 29                           y                       y
# 30                           y                       y
# 31                           y                       n
# 32                           n                       y
# 33                           n                       y
# 34                           n                       y
# 35                           y                       y
# 36                           y                       n
# 37                           y                       n
# 38                           y                       n
# 39                           n                       n
# 40                           y                       n
# 41                           y                       n
# 42                           y                       n
# 43                           y                       n
# 44                           y                       n
# 45                           y                       y
# 46                           n                       y
# 47                           n                       y
# 48                           n                       y
# 49                           y                       n
# 50                           y                       y
# 51                           y                       y
# 52                           y                       n
# 53                           y                       y
# 54                           n                       n
# 55                           y                       n
# 56                           n                       y
# 57                           n                       y
#
#    aid-to-nicaraguan-contras mx-missile immigration  \
# 0                          n          n           n
# 1                          n          n           n
# 2                          y          y           n
# 3                          y          y           n
# 4                          y          y           y
# 5                          y          y           n
# 6                          y          y           n
# 7                          y          y           n
# 8                          y          y           n
# 9                          n          n           n
# 10                         y          y           y
# 11                         n          n           n
# 12                         y          y           n
# 13                         n          n           n
# 14                         n          n           n
# 15                         n          n           y
# 16                         y          y           y
# 17                         y          y           n
# 18                         y          y           n
# 19                         y          y           n
# 20                         y          n           n
# 21                         y          y           n
# 22                         n          n           y
# 23                         n          n           y
# 24                         n          n           y
# 25                         n          n           y
# 26                         n          n           y
# 27                         n          n           n
# 28                         y          y           n
# 29                         n          n           n
# 30                         n          n           n
# 31                         n          n           y
# 32                         y          y           n
# 33                         y          y           y
# 34                         n          y           y
# 35                         y          y           y
# 36                         n          n           y
# 37                         y          y           y
# 38                         n          n           y
# 39                         n          n           y
# 40                         n          n           y
# 41                         n          n           n
# 42                         n          n           y
# 43                         n          n           y
# 44                         n          n           n
# 45                         n          y           y
# 46                         y          y           y
# 47                         y          y           y
# 48                         n          y           y
# 49                         n          n           n
# 50                         n          n           y
# 51                         y          y           y
# 52                         n          n           n
# 53                         n          n           n
# 54                         y          y           n
# 55                         n          n           n
# 56                         y          y           y
# 57                         y          y           n
#
#    synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                             n                  n                      y
# 1                             n                  y                      y
# 2                             y                  n                      n
# 3                             n                  n                      n
# 4                             n                  n                      n
# 5                             y                  n                      n
# 6                             y                  n                      n
# 7                             n                  y                      y
# 8                             y                  n                      n
# 9                             n                  y                      y
# 10                            n                  n                      y
# 11                            n                  y                      y
# 12                            n                  n                      n
# 13                            n                  y                      y
# 14                            n                  n                      y
# 15                            n                  y                      y
# 16                            y                  n                      y
# 17                            n                  n                      n
# 18                            n                  n                      n
# 19                            n                  n                      n
# 20                            n                  n                      n
# 21                            y                  n                      n
# 22                            n                  y                      y
# 23                            y                  y                      y
# 24                            y                  y                      y
# 25                            n                  y                      y
# 26                            n                  y                      y
# 27                            n                  y                      y
# 28                            y                  n                      n
# 29                            n                  y                      y
# 30                            y                  y                      y
# 31                            n                  y                      y
# 32                            n                  n                      n
# 33                            y                  n                      n
# 34                            n                  n                      y
# 35                            y                  n                      n
# 36                            y                  n                      y
# 37                            y                  y                      y
# 38                            y                  n                      y
# 39                            n                  y                      y
# 40                            n                  y                      y
# 41                            n                  y                      y
# 42                            y                  y                      y
# 43                            n                  y                      y
# 44                            n                  y                      y
# 45                            y                  n                      y
# 46                            n                  n                      n
# 47                            y                  n                      n
# 48                            y                  n                      n
# 49                            n                  n                      n
# 50                            y                  n                      n
# 51                            n                  n                      n
# 52                            y                  y                      n
# 53                            y                  n                      n
# 54                            y                  n                      n
# 55                            n                  y                      y
# 56                            n                  n                      n
# 57                            y                  n                      n
#
#    crime duty-free-exports export-administration-act-south-africa
# 0      y                 y                                      y
# 1      y                 n                                      y
# 2      n                 y                                      y
# 3      n                 y                                      y
# 4      n                 y                                      y
# 5      n                 y                                      y
# 6      n                 y                                      y
# 7      y                 n                                      y
# 8      n                 y                                      y
# 9      y                 n                                      n
# 10     n                 y                                      y
# 11     y                 n                                      y
# 12     n                 y                                      y
# 13     y                 n                                      n
# 14     y                 n                                      y
# 15     y                 n                                      n
# 16     n                 y                                      y
# 17     n                 n                                      y
# 18     n                 y                                      y
# 19     n                 n                                      y
# 20     y                 n                                      y
# 21     n                 y                                      y
# 22     y                 n                                      n
# 23     y                 n                                      n
# 24     y                 n                                      y
# 25     y                 n                                      y
# 26     y                 n                                      y
# 27     y                 n                                      n
# 28     n                 n                                      y
# 29     y                 n                                      y
# 30     y                 n                                      y
# 31     y                 n                                      n
# 32     n                 y                                      y
# 33     y                 n                                      y
# 34     y                 n                                      y
# 35     y                 y                                      y
# 36     y                 n                                      n
# 37     y                 n                                      y
# 38     y                 n                                      y
# 39     y                 n                                      n
# 40     y                 n                                      y
# 41     y                 n                                      n
# 42     y                 n                                      y
# 43     y                 n                                      n
# 44     y                 n                                      n
# 45     y                 n                                      y
# 46     n                 y                                      y
# 47     n                 y                                      y
# 48     n                 y                                      y
# 49     n                 n                                      y
# 50     y                 n                                      y
# 51     n                 n                                      y
# 52     y                 n                                      y
# 53     y                 n                                      y
# 54     n                 y                                      y
# 55     y                 n                                      y
# 56     n                 y                                      y
# 57     n                 y                                      y

# %%
def bestAttribute(X_DataFrame , y_DataFrame):
    
    infoGain = [] #To store every information gain for all features
    
    for i in range(len(X_DataFrame.columns)):
        infoGain.append(information_gain(X , i , y))
    
    #print(infoGain)
    maxValue = 0.0
    index = 0
    bestFeature = ""
    
    for i in range(len(infoGain)):
        if maxValue < infoGain[i]:
            maxValue = infoGain[i]
            index = i
            #bestFeature = col_names[i]
    
    counter = 0
    for x in X_DataFrame.columns:
        if counter == i:
            bestFeature = x
            break
        else:
            counter = counter + 1
    
    return bestFeature , index

# %%
fea , inde = bestAttribute(X_train , y_train)
print(fea , " " , inde)
# Out:
# export-administration-act-south-africa   3

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 7 : </b>
#        Create the Decision Tree
#  </p>
# </div>

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 7.1 : </b>
#        Create Node Class
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
class Node:
    def __init__(self):
        self.left = None
        self.right = None
        self.attribute = ""
        self.value = ""
        self.classDemocrat = 0
        self.classRepublican = 0
        self.label = None
    
    def addNode(self , attribute , value , classRepublican = 0 , classDemocrat = 0 ):
        self.attribute = attribute
        self.classDemocrat = classDemocrat
        self.classRepublican = classRepublican
        self.value = value

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 7.2 : </b>
#        Create Decision Tree Class
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
class DecisionTree:
    def __init__(self):
        self.root = Node()
        self.root.addNode('temp' , "temp")
        
    def createDecisionTree(self , X_DataFrame , y_DataFrame , tree):
        
        X = X_DataFrame.to_numpy()
        #print(feature_array)
        
        y = (y_DataFrame.to_numpy()).reshape(len(y_DataFrame) , 1)
        
        total = X.shape[0]
        
        ones = 0 #To count how many number of democrat
        zeros = 0 #To count how many number of republican
        for i in range(len(y)):
            if y[i] == "republican" :
                ones = ones + 1
            else:
                zeros = zeros + 1
        
        if X.shape[1] == 1 or total == ones or total == zeros:
            if zeros >= ones:
                tree.label = 'democrat'
            else:
                tree.label = 'republican'
            return   
        
        else:
            bestFeature , index = bestAttribute(X_DataFrame , y_DataFrame) #it will hold the name of the feature
            tree.left = Node()
            tree.right = Node()
            
            """ Count the number of reoublican with the only exisiting of the bestFeature"""
            
            
            republicanCountYes = 0
            democratCountYes = 0
            for i in range(len(X)):
                if y[i] == "republican" and X[i , index] == 'y':
                    republicanCountYes = republicanCountYes + 1
                elif y[i] == "democrat" and X[i , index] == 'y':
                    democratCountYes = democratCountYes + 1 
            
            
            republicanCountNo = 0
            democratCountNo = 0
            for i in range(len(X)):
                if y[i] == "republican" and X[i , index] == 'n':
                    republicanCountNo = republicanCountNo + 1
                elif y[i] == "democrat" and X[i , index] == 'n':
                    democratCountNo = democratCountNo + 1 
                    
            tree.left.addNode(bestFeature , "y" , republicanCountYes , democratCountYes)
            tree.right.addNode(bestFeature , "n" , republicanCountNo , democratCountNo)
            
            self.createDecisionTree(X_DataFrame[X_DataFrame[bestFeature]==0].drop([bestFeature], axis=1) , y_DataFrame , tree.left)
            self.createDecisionTree(X_DataFrame[X_DataFrame[bestFeature]==0].drop([bestFeature], axis=1) , y_DataFrame , tree.right)
            
    def predict(self , data , root):
        if root.label is not None:
            return root.label
        elif data[root.left.attribute][data.index.tolist()[0]] == 1:
            return self.predict(data, root.right)
        else:
            return self.predict(data, root.left)
        
    def countNodes(self,node):
        if(node.left is not None and node.right is not None):
            return 2 + self.countNodes(node.left) + self.countNodes(node.right)
        return 0

    
    def countLeaf(self,node):
        if(node.left is None and node.right is None):
            return 1
        return self.countLeaf(node.left) + self.countLeaf(node.right)
        
    

    
def calculateAccuracy(data , label , tree):
    y = (label.to_numpy()).reshape(len(label) , 1)
    correctCount = 0
    for i in data.index:
        val = tree.predict(data.iloc[i:i+1, :] , tree.root)
        if val == y[i]:
            correctCount = correctCount + 1
    return correctCount/data.shape[0]*100

# %%
model = DecisionTree()

# %%
model.createDecisionTree(X_train , y_train , model.root)

# %%
accuracy = calculateAccuracy(X_test , y_test , model)

# %%
print('Accuracy without handling overfiiting and underfitting = %.2f'%accuracy , '%')
# Out:
# Accuracy without handling overfiiting and underfitting = 51.72 %

# %%
print("Total number of nodes in the tree = "+ str(model.countNodes(model.root)))
# Out:
# Total number of nodes in the tree = 65534

# %% [markdown]
# ## Part 1
# ----------------------------------------------------------------------------------
#
# Use the voting data to train a decision tree to predict political party (Democrat or
# Republican) based on the voting record. Use 25% of the members of congress for
# training and the rest for testing. Rerun this experiment five times and notice the
# impact of different random splits of the data into training and test sets. Report the
# sizes and accuracies of these trees in each experiment.

# %%
for i in range(5):
    data = dataset.sample(frac = 0.25)
    X = data[col_names]
    y = data[['Class Name']]
    indeces = len(X)
    splitIndex = int(np.ceil(0.25 * indeces)) 
    
    X_train = X.iloc[0:splitIndex , :].values
    X_train = pd.DataFrame(X_train , columns = col_names)
    
    y_train = y.iloc[0:splitIndex , :].values
    y_train = pd.DataFrame(y_train , columns = ['Class Name'])
    
    X_test = X.iloc[splitIndex: , :].values
    X_test = pd.DataFrame(X_test , columns = col_names)
    
    y_test = y.iloc[splitIndex: , :].values
    y_test = pd.DataFrame(y_test , columns = ['Class Name'])
    
    model = DecisionTree()
    model.createDecisionTree(X_train , y_train , model.root)
    
    accuracy = calculateAccuracy(X_test , y_test , model)
    print('Accuracy without handling overfiiting and underfitting = %.2f'%accuracy , '% for iteration ' , i)
    print("Total number of nodes in the tree = "+ str(model.countNodes(model.root)) , ' for iteration ' , i)
    print("***************************************************************")
# Out:
# Accuracy without handling overfiiting and underfitting = 48.84 % for iteration  0
# Total number of nodes in the tree = 65534 % for iteration  0
# Accuracy without handling overfiiting and underfitting = 53.49 % for iteration  1
# Total number of nodes in the tree = 65534 % for iteration  1
# Accuracy without handling overfiiting and underfitting = 58.14 % for iteration  2
# Total number of nodes in the tree = 65534 % for iteration  2
# Accuracy without handling overfiiting and underfitting = 46.51 % for iteration  3
# Total number of nodes in the tree = 65534 % for iteration  3
# Accuracy without handling overfiiting and underfitting = 55.81 % for iteration  4
# Total number of nodes in the tree = 65534 % for iteration  4

# %% [markdown]
# ## Part 2
# ----------------------------------------------------------------------------------
#
# Measure the impact of training set size on the accuracy and the size of the learned
# tree. Consider training set sizes in the range (30-70%). Because of the high variance
# due to random splits repeat the experiment with five different random seeds for each
# training set size then report the mean, maximum and minimum accuracies at each
# training set size. Also measure the mean, max and min tree size.
# Start with training data size 30%, 40 Until you reach 70%.
# The data set contained many missing values , i.e., votes in which a member of
# congress failed to participate. To solve those issue insert for each absent
# vote the voting decision of the majority.

# %%
splitSize = [0.30 , 0.40 , 0.50 , 0.60 , 0.70]
accuracies = []
treeSize = []

for i in range(5):
    data = dataset.sample(frac = splitSize[i])
    X = data[col_names]
    y = data[['Class Name']]
    indeces = len(X)
    splitIndex = int(np.ceil(splitSize[i] * indeces)) 
    
    X_train = X.iloc[0:splitIndex , :].values
    X_train = pd.DataFrame(X_train , columns = col_names)
    
    y_train = y.iloc[0:splitIndex , :].values
    y_train = pd.DataFrame(y_train , columns = ['Class Name'])
    
    X_test = X.iloc[splitIndex: , :].values
    X_test = pd.DataFrame(X_test , columns = col_names)
    
    y_test = y.iloc[splitIndex: , :].values
    y_test = pd.DataFrame(y_test , columns = ['Class Name'])
    
    model = DecisionTree()
    model.createDecisionTree(X_train , y_train , model.root)
    
    accuracy = calculateAccuracy(X_test , y_test , model)
    accuracies.append(accuracy)
    treeSize.append(model.countNodes(model.root))
    
    print('Accuracy without handling overfiiting and underfitting = %.2f'%accuracy , '% for iteration ' , i)
    print("Total number of nodes in the tree = "+ str(model.countNodes(model.root)) , ' for iteration ' , i)
    print("***************************************************************")
# Out:
# Accuracy without handling overfiiting and underfitting = 48.98 % for iteration  0
# Total number of nodes in the tree = 65534  for iteration  0
# ***************************************************************
# Accuracy without handling overfiiting and underfitting = 50.91 % for iteration  1
# Total number of nodes in the tree = 65534  for iteration  1
# ***************************************************************
# Accuracy without handling overfiiting and underfitting = 51.72 % for iteration  2
# Total number of nodes in the tree = 65534  for iteration  2
# ***************************************************************
# Accuracy without handling overfiiting and underfitting = 54.55 % for iteration  3
# Total number of nodes in the tree = 65534  for iteration  3
# ***************************************************************
# Accuracy without handling overfiiting and underfitting = 58.33 % for iteration  4
# Total number of nodes in the tree = 65534  for iteration  4
# ***************************************************************

# %%
print(accuracies)
# Out:
# [48.97959183673469, 50.90909090909091, 51.724137931034484, 54.54545454545454, 58.333333333333336]

# %%
print(treeSize)
# Out:
# [65534, 65534, 65534, 65534, 65534]

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 7.3 : </b>
#        Get the maximum and minimum accuracy , and calculate the mean accuracies
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
max_accuracy = max(accuracies)
max_index = accuracies.index(max_accuracy)
print("Maximum accuracy = " , max_accuracy , " with training size = " , splitSize[max_index] * 100 , " %")

print("*******************************************************")

min_accuracy = min(accuracies)
min_index = accuracies.index(min_accuracy)
print("Minimum accuracy = " , min_accuracy , " with training size = " , splitSize[min_index] * 100 , " %")

print("*******************************************************")

total_accuracy = sum(accuracies)
mean = total_accuracy / len(splitSize)
print("Mean Accuracies = " , mean)
# Out:
# Maximum accuracy =  58.333333333333336  with training size =  70.0  %
# *******************************************************
# Minimum accuracy =  48.97959183673469  with training size =  30.0  %
# *******************************************************
# Mean Accuracies =  52.89832171112958

# %% [markdown]
# <div style="color:black; border-radius: 5px; background-color:#E7E9EB;padding: 10px;">
#     <p style="  padding: 5px;"><b>Finding 7.4 : </b>
#        Get the maximum and minimum tree size , and calculate the mean tree sizes
#  </p>
# </div>
#
# <div style="color:black; border-radius: 5px; margin: 5px 0;font-family:'Source Sans Pro', sans-serif;">
#  <h4 style="border-left: 4px solid #96D4D4; background: #D9EEE1; padding: 5px; font-family:'Source Sans Pro', sans-serif;">Code</h4>
# </div>

# %%
max_size = max(treeSize)
max_index = treeSize.index(max_size)
print("Maximum tree size = " , max_size , " with training size = " , splitSize[max_index] * 100 , " %")

print("*******************************************************")

min_size = min(treeSize)
min_index = treeSize.index(min_size)
print("Minimum tree size = " , min_size , " with training size = " , splitSize[min_index] * 100 , " %")

print("*******************************************************")

total_size = sum(treeSize)
mean = total_size / len(splitSize)
print("Mean Sizes = " , mean)
# Out:
# Maximum tree size =  65534  with training size =  30.0  %
# *******************************************************
# Minimum tree size =  65534  with training size =  30.0  %
# *******************************************************
# Mean Sizes =  65534.0
